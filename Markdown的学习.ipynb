# %% [markdown]
# # Markdown

# %% [markdown]
# 一种常用的文本保存形式，只用文字符号，让各个设备，软件都能知道你想以怎么样的格式输出文字

# %% [markdown]
# 1.# ## ###分别表示一二三级标题

# %% [markdown]
# 2.“>”表示一段引用，显示格式如下

# %% [markdown]
# >这是一段引用

# %% [markdown]
# 3."-"短横线表示无序列表

# %% [markdown]
# - 第一步
# - 第二步
# - 第三步

# %% [markdown]
# 4.“---”表示分割线

# %% [markdown]
# 一二三
# ---
# 四五六

# %% [markdown]
# 5.“- [ ] "表示任务列表，里面加可以打勾

# %% [markdown]
# - [ ] 吃饭
# - [x] 睡觉

# %% [markdown]
# 6.``` 加语言类型表示代码块

# %% [markdown]
# ``` c
# int main(void)
# {return 0;
# }

# %% [markdown]
# 7.数学公式用前面两个美元符号后面两个美元符号包起来

# %% [markdown]
# $$
# \frac{\partial f}{\partial x}=2\sqrt{a}x
# $$

# %% [markdown]
# 8.换行：第一行行尾两个空格加回车

# %% [markdown]
# abd
# efg
